# %% [markdown]
# # 04 Feature engineering
# Includes Haversine `distance_km` and coordinates.

# %%
from src.data.clean import clean_clean_dataset
from src.data.load import load_clean_dataset
from src.features.geo_features import add_geographic_features
df = add_geographic_features(clean_clean_dataset(load_clean_dataset()).head(1000))
print(df[['source_city','destination_city','distance_km']].head())
