# %% [markdown]
# # 05–07 Training, comparison, importance
# Prefer `python -m src.models.train` then read `models/metrics.json` and `models/feature_importance.json`.

# %%
import json
from pathlib import Path
print(json.loads(Path('models/metrics.json').read_text())['best_model'])
