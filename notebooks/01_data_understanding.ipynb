# %% [markdown]
# # 01 Data understanding
# Inspect the three CSVs. Do not assume columns.

# %%
from pathlib import Path
import pandas as pd
root = Path('..') if not Path('Clean_Dataset.csv').exists() else Path('.')
for name in ['Clean_Dataset.csv','business.csv','economy.csv']:
    df = pd.read_csv(root/name if (root/name).exists() else name)
    print(name, df.shape, list(df.columns))
