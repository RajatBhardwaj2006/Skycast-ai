# %% [markdown]
# # 07 Feature importance

# %%
import json, pandas as pd
from pathlib import Path
print(pd.DataFrame(json.loads(Path('models/feature_importance.json').read_text())['features']).head(10))
